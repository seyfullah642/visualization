# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math

# %%
diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"

# %%
diamonds_df = pd.read_csv(diamonds_url)

# %%
#diamonds_df = sns.load_dataset('diamonds')

# %%
#diamonds_df = pd.read_csv(diamonds_url, usecols=['carat','cut','color','clarity'])

# %%
#diamonds_df

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df.cut.nunique()
# Out:
# 5

# %%
diamonds_df.color.nunique()
# Out:
# 7

# %%
diamonds_df.clarity.nunique()
# Out:
# 8

# %%
diamonds_df.shape
# Out:
# (53940, 10)

# %%
diamonds_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
diamonds_df.describe(include=object)
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
diamonds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds_df['price_per_carat'] = diamonds_df['price'] / diamonds_df['carat']

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat
# 0      1417.391304
# 1      1552.380952
# 2      1421.739130
# 3      1151.724138
# 4      1080.645161

# %%
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat'] > 3500, 1, 0)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high
# 0      1417.391304                        0
# 1      1552.380952                        0
# 2      1421.739130                        0
# 3      1151.724138                        0
# 4      1080.645161                        0

# %%
diamonds_df['price'] = diamonds_df['price'] * 1.3

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high
# 0      1417.391304                        0
# 1      1552.380952                        0
# 2      1421.739130                        0
# 3      1151.724138                        0
# 4      1080.645161                        0

# %%
diamonds_df['rounded_price'] = diamonds_df['price'].apply(math.ceil)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436

# %%
diamonds_df['rounded_price_to_100multiple'] = diamonds_df['price'].apply(lambda x: math.ceil(x/100) * 100)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436
#
#    rounded_price_to_100multiple
# 0                           500
# 1                           500
# 2                           500
# 3                           500
# 4                           500

# %%
diamonds_df.drop(['rounded_price_to_100multiple'], axis=1, inplace=True)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436

# %%
def get_100_multiple_ceil(x):
    y = math.ceil(x/100) * 100
    return y

diamonds_df['rounded_price_to_100multiple'] = diamonds_df['price'].apply(get_100_multiple_ceil)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436
#
#    rounded_price_to_100multiple
# 0                           500
# 1                           500
# 2                           500
# 3                           500
# 4                           500

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1788f783e4e1> in <module>
# ----> 1 diamonds_df.loc(diamonds_df['cut'] == 'Fair')
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     582
#     583         if axis is not None:
# --> 584             axis = self.obj._get_axis_number(axis)
#     585         new_self.axis = axis
#     586         return new_self
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#     370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in __hash__(self)
#    1663
#    1664     def __hash__(self):
# -> 1665         raise TypeError(
#    1666             f"{repr(type(self).__name__)} objects are mutable, "
#    1667             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
